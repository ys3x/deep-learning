# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
# !conda install -y tqdm pillow matplotlib

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    image_input = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name='image_input')
    z_input = tf.placeholder(tf.float32, (None, z_dim), name='z_input')
    lr = tf.placeholder(tf.float32, name='learning_rate')

    return image_input, z_input, lr


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    kernel_size = 5
    alpha = 0.2
    with tf.variable_scope('discriminator', reuse=reuse):

        # (28, 82, 3) -> (14,14, 128) -> (7, 7, 256) -> Flatten -> FC
        
        # input: (None, 28, 28, 3) 
        x = images

        # Conv2D(stride=2) -> output: (None, 14, 14, 128),  note: we don't use BatchNorm for the 1st layer
        x = tf.layers.conv2d(x, 128, kernel_size, strides=2, padding='same')
        x = tf.maximum(alpha*x, x)
        
        # Conv2D(stride=2) -> output(None, 7, 7, 256)
        x = tf.layers.conv2d(x, 256, kernel_size, strides=2, padding='same')
        x = tf.layers.batch_normalization(x)
        x = tf.maximum(alpha*x, x)

        # Flatten
        x = tf.reshape(x, (-1, 7 * 7 * 256))
        
        # FC/Logits
        logits = tf.layers.dense(x, 1, activation=None)

        # Sigmoid
        output = tf.sigmoid(logits)

    return output, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    alpha = 0.2
    kernel_size = 5
    
    # When training, we want reuse the vars, but 
    with tf.variable_scope('generator', reuse=(not is_train)):

        # FC -> Reshape_to_Cube -> Conv2D_T -> Conv2D_T -> Tanh
        
        # FC /wo activation
        x = z
        x = tf.layers.dense(x, 7*7*256, activation=None)
        
        # Reshape to the cube
        x = tf.reshape(x, (-1, 7, 7, 256)) 
        x = tf.layers.batch_normalization(x, training=is_train)
        x = tf.maximum(alpha*x, x)
        
        # Conv2D_T -> (None, 14, 14, 128)
        x = tf.layers.conv2d_transpose(x, 128, kernel_size, strides=2, padding='same', activation=None)
        x = tf.layers.batch_normalization(x, training=is_train)
        x = tf.maximum(alpha*x, x)
        
        # Conv2D_T -> (None, 28, 28, out_channel_dim=1 or 3)
        x = tf.layers.conv2d_transpose(x, out_channel_dim, kernel_size, strides=2, padding='same', activation=None)
        #x = tf.layers.batch_normalization(x, training=is_train)
        #x = tf.maximum(alpha*x, x)
    
        # Tanh
        output = tf.tanh(x)
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    g_model = generator(input_z, out_channel_dim, is_train=True)
    d_model_real, d_logits_real = discriminator(input_real, reuse=False)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)
    
    sigmoid_ce_with_logits = tf.nn.sigmoid_cross_entropy_with_logits

    d_loss_real = tf.reduce_mean(sigmoid_ce_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real) * 0.9))
    d_loss_fake = tf.reduce_mean(sigmoid_ce_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake) * 0.1))
    d_loss = d_loss_real + d_loss_fake
    
    g_loss = tf.reduce_mean(sigmoid_ce_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)
        
    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    image_width, image_height, image_channels = data_shape[1:] # data_shape=(n_batches, w, h, ch)
    input_real, input_z, lr = model_inputs(image_width, image_height, image_channels, z_dim)
    print('input data_shape: ', data_shape)
    print('input_real: {}, input_z: {}, lr: {}'.format(input_real.get_shape(), input_z.get_shape(), learning_rate))

    d_loss, g_loss = model_loss(input_real, input_z, image_channels)
    d_train_opt, g_train_opt = model_opt(d_loss, g_loss, lr, beta1)
    
    batch_step = 0
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            
            # batch_images: (None, W, H, Ch)
            for batch_images in get_batches(batch_size):
                
                # TODO: Train Model
                batch_step += 1
                
                # As Generator output is -1.0~1.0, amplify real image to -1.0~1.0 (as they were -0.5 to 0.5)
                batch_images *= 2.0

                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                # Run optimizers 
                _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z, lr: learning_rate})
                _ = sess.run(g_train_opt, feed_dict={input_z: batch_z, lr: learning_rate}) 

                # Show training status and images
                if batch_step % 100 == 0:
                    # Train status
                    train_loss_d = d_loss.eval({input_real: batch_images, input_z: batch_z })
                    train_loss_g = g_loss.eval({input_z: batch_z})

                    print("Epoch {}/{}, Batch Step:{}, Proc Imgs: {}k ...".format(epoch_i+1, epoch_count, batch_step, batch_step*batch_size//1000),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                
                if batch_step % 500 == 0:
                    show_generator_output(sess, 5**2, input_z, image_channels, data_image_mode)

        # last
        show_generator_output(sess, 5**2, input_z, image_channels, data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 100
z_dim = 100
learning_rate = 1e-3
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# input data_shape:  (60000, 28, 28, 1)
# input_real: (?, 28, 28, 1), input_z: (?, 100), lr: 0.001
# Epoch 1/2, Batch Step:100, Proc Imgs: 10k ... Discriminator Loss: 1.2613... Generator Loss: 0.7848
# Epoch 1/2, Batch Step:200, Proc Imgs: 20k ... Discriminator Loss: 1.2015... Generator Loss: 1.4377
# Epoch 1/2, Batch Step:300, Proc Imgs: 30k ... Discriminator Loss: 1.1604... Generator Loss: 0.7311
# Epoch 1/2, Batch Step:400, Proc Imgs: 40k ... Discriminator Loss: 1.4132... Generator Loss: 1.7201
# Epoch 1/2, Batch Step:500, Proc Imgs: 50k ... Discriminator Loss: 1.1360... Generator Loss: 0.9756
# Epoch 1/2, Batch Step:600, Proc Imgs: 60k ... Discriminator Loss: 1.3335... Generator Loss: 0.6243
# Epoch 2/2, Batch Step:700, Proc Imgs: 70k ... Discriminator Loss: 1.2207... Generator Loss: 1.4582
# Epoch 2/2, Batch Step:800, Proc Imgs: 80k ... Discriminator Loss: 1.2056... Generator Loss: 0.9723
# Epoch 2/2, Batch Step:900, Proc Imgs: 90k ... Discriminator Loss: 1.0883... Generator Loss: 0.9506
# Epoch 2/2, Batch Step:1000, Proc Imgs: 100k ... Discriminator Loss: 1.2868... Generator Loss: 0.6543
# Epoch 2/2, Batch Step:1100, Proc Imgs: 110k ... Discriminator Loss: 1.1446... Generator Loss: 1.1193
# Epoch 2/2, Batch Step:1200, Proc Imgs: 120k ... Discriminator Loss: 1.0213... Generator Loss: 1.0280

# %%
batch_size = 100
z_dim = 100
learning_rate = 2e-4
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# input data_shape:  (60000, 28, 28, 1)
# input_real: (?, 28, 28, 1), input_z: (?, 100), lr: 0.0002
# Epoch 1/2, Batch Step:100, Proc Imgs: 10k ... Discriminator Loss: 1.3192... Generator Loss: 1.0055
# Epoch 1/2, Batch Step:200, Proc Imgs: 20k ... Discriminator Loss: 1.3962... Generator Loss: 0.6270
# Epoch 1/2, Batch Step:300, Proc Imgs: 30k ... Discriminator Loss: 1.4182... Generator Loss: 0.7035
# Epoch 1/2, Batch Step:400, Proc Imgs: 40k ... Discriminator Loss: 1.1906... Generator Loss: 1.2743
# Epoch 1/2, Batch Step:500, Proc Imgs: 50k ... Discriminator Loss: 1.1108... Generator Loss: 0.9030
# Epoch 1/2, Batch Step:600, Proc Imgs: 60k ... Discriminator Loss: 1.3198... Generator Loss: 0.6096
# Epoch 2/2, Batch Step:700, Proc Imgs: 70k ... Discriminator Loss: 1.6319... Generator Loss: 1.9283
# Epoch 2/2, Batch Step:800, Proc Imgs: 80k ... Discriminator Loss: 1.2558... Generator Loss: 0.9753
# Epoch 2/2, Batch Step:900, Proc Imgs: 90k ... Discriminator Loss: 1.2094... Generator Loss: 1.0285
# Epoch 2/2, Batch Step:1000, Proc Imgs: 100k ... Discriminator Loss: 1.3229... Generator Loss: 0.9678
# Epoch 2/2, Batch Step:1100, Proc Imgs: 110k ... Discriminator Loss: 1.2523... Generator Loss: 1.0500
# Epoch 2/2, Batch Step:1200, Proc Imgs: 120k ... Discriminator Loss: 1.3284... Generator Loss: 0.6032

# %%
batch_size = 100
z_dim = 100
learning_rate = 1e-3
beta1 = 0.2

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# input data_shape:  (60000, 28, 28, 1)
# input_real: (?, 28, 28, 1), input_z: (?, 100), lr: 0.001
# Epoch 1/2, Batch Step:100, Proc Imgs: 10k ... Discriminator Loss: 1.2365... Generator Loss: 0.8659
# Epoch 1/2, Batch Step:200, Proc Imgs: 20k ... Discriminator Loss: 1.3131... Generator Loss: 0.9276
# Epoch 1/2, Batch Step:300, Proc Imgs: 30k ... Discriminator Loss: 1.3127... Generator Loss: 0.9295
# Epoch 1/2, Batch Step:400, Proc Imgs: 40k ... Discriminator Loss: 1.4010... Generator Loss: 0.5226
# Epoch 1/2, Batch Step:500, Proc Imgs: 50k ... Discriminator Loss: 1.4142... Generator Loss: 0.5524
# Epoch 1/2, Batch Step:600, Proc Imgs: 60k ... Discriminator Loss: 1.4177... Generator Loss: 0.5373
# Epoch 2/2, Batch Step:700, Proc Imgs: 70k ... Discriminator Loss: 1.2775... Generator Loss: 1.0589
# Epoch 2/2, Batch Step:800, Proc Imgs: 80k ... Discriminator Loss: 1.3194... Generator Loss: 0.8156
# Epoch 2/2, Batch Step:900, Proc Imgs: 90k ... Discriminator Loss: 1.2478... Generator Loss: 0.8116
# Epoch 2/2, Batch Step:1000, Proc Imgs: 100k ... Discriminator Loss: 1.2856... Generator Loss: 0.6857
# Epoch 2/2, Batch Step:1100, Proc Imgs: 110k ... Discriminator Loss: 1.2996... Generator Loss: 1.1741
# Epoch 2/2, Batch Step:1200, Proc Imgs: 120k ... Discriminator Loss: 1.3259... Generator Loss: 0.6465

# %%
batch_size = 100
z_dim = 100
learning_rate = 1e-3
beta1 = 0.8

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# input data_shape:  (60000, 28, 28, 1)
# input_real: (?, 28, 28, 1), input_z: (?, 100), lr: 0.001
# Epoch 1/2, Batch Step:100, Proc Imgs: 10k ... Discriminator Loss: 0.4214... Generator Loss: 3.7313
# Epoch 1/2, Batch Step:200, Proc Imgs: 20k ... Discriminator Loss: 0.7155... Generator Loss: 3.4811
# Epoch 1/2, Batch Step:300, Proc Imgs: 30k ... Discriminator Loss: 0.8078... Generator Loss: 2.7323
# Epoch 1/2, Batch Step:400, Proc Imgs: 40k ... Discriminator Loss: 0.5109... Generator Loss: 3.3493
# Epoch 1/2, Batch Step:500, Proc Imgs: 50k ... Discriminator Loss: 0.7179... Generator Loss: 2.1207
# Epoch 1/2, Batch Step:600, Proc Imgs: 60k ... Discriminator Loss: 0.7666... Generator Loss: 3.0397
# Epoch 2/2, Batch Step:700, Proc Imgs: 70k ... Discriminator Loss: 0.7845... Generator Loss: 2.3468
# Epoch 2/2, Batch Step:800, Proc Imgs: 80k ... Discriminator Loss: 0.8512... Generator Loss: 1.8245
# Epoch 2/2, Batch Step:900, Proc Imgs: 90k ... Discriminator Loss: 0.9189... Generator Loss: 1.8898
# Epoch 2/2, Batch Step:1000, Proc Imgs: 100k ... Discriminator Loss: 0.8129... Generator Loss: 2.3308
# Epoch 2/2, Batch Step:1100, Proc Imgs: 110k ... Discriminator Loss: 0.7346... Generator Loss: 2.4416
# Epoch 2/2, Batch Step:1200, Proc Imgs: 120k ... Discriminator Loss: 0.6795... Generator Loss: 2.5735

# %%
batch_size = 100
z_dim = 100
learning_rate = 2e-4
beta1 = 0.2

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# input data_shape:  (60000, 28, 28, 1)
# input_real: (?, 28, 28, 1), input_z: (?, 100), lr: 0.0002
# Epoch 1/2, Batch Step:100, Proc Imgs: 10k ... Discriminator Loss: 1.3272... Generator Loss: 0.7797
# Epoch 1/2, Batch Step:200, Proc Imgs: 20k ... Discriminator Loss: 1.3809... Generator Loss: 0.7686
# Epoch 1/2, Batch Step:300, Proc Imgs: 30k ... Discriminator Loss: 1.2785... Generator Loss: 1.0334
# Epoch 1/2, Batch Step:400, Proc Imgs: 40k ... Discriminator Loss: 1.3028... Generator Loss: 1.2031
# Epoch 1/2, Batch Step:500, Proc Imgs: 50k ... Discriminator Loss: 1.2776... Generator Loss: 0.8650
# Epoch 1/2, Batch Step:600, Proc Imgs: 60k ... Discriminator Loss: 1.2917... Generator Loss: 0.7812
# Epoch 2/2, Batch Step:700, Proc Imgs: 70k ... Discriminator Loss: 1.4669... Generator Loss: 0.4801
# Epoch 2/2, Batch Step:800, Proc Imgs: 80k ... Discriminator Loss: 1.3410... Generator Loss: 0.9402
# Epoch 2/2, Batch Step:900, Proc Imgs: 90k ... Discriminator Loss: 1.2898... Generator Loss: 1.0061
# Epoch 2/2, Batch Step:1000, Proc Imgs: 100k ... Discriminator Loss: 1.3096... Generator Loss: 0.6773
# Epoch 2/2, Batch Step:1100, Proc Imgs: 110k ... Discriminator Loss: 1.3031... Generator Loss: 0.8410
# Epoch 2/2, Batch Step:1200, Proc Imgs: 120k ... Discriminator Loss: 1.4285... Generator Loss: 0.5127

# %%
batch_size = 100
z_dim = 100
learning_rate = 2e-4
beta1 = 0.8

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# input data_shape:  (60000, 28, 28, 1)
# input_real: (?, 28, 28, 1), input_z: (?, 100), lr: 0.0002
# Epoch 1/2, Batch Step:100, Proc Imgs: 10k ... Discriminator Loss: 0.5860... Generator Loss: 3.2062
# Epoch 1/2, Batch Step:200, Proc Imgs: 20k ... Discriminator Loss: 0.7083... Generator Loss: 1.6146
# Epoch 1/2, Batch Step:300, Proc Imgs: 30k ... Discriminator Loss: 0.7620... Generator Loss: 1.5622
# Epoch 1/2, Batch Step:400, Proc Imgs: 40k ... Discriminator Loss: 1.1017... Generator Loss: 1.0040
# Epoch 1/2, Batch Step:500, Proc Imgs: 50k ... Discriminator Loss: 0.8522... Generator Loss: 1.6854
# Epoch 1/2, Batch Step:600, Proc Imgs: 60k ... Discriminator Loss: 0.8925... Generator Loss: 1.5431
# Epoch 2/2, Batch Step:700, Proc Imgs: 70k ... Discriminator Loss: 0.9608... Generator Loss: 1.4843
# Epoch 2/2, Batch Step:800, Proc Imgs: 80k ... Discriminator Loss: 0.8442... Generator Loss: 1.6001
# Epoch 2/2, Batch Step:900, Proc Imgs: 90k ... Discriminator Loss: 0.8543... Generator Loss: 1.4602
# Epoch 2/2, Batch Step:1000, Proc Imgs: 100k ... Discriminator Loss: 1.0370... Generator Loss: 1.3766
# Epoch 2/2, Batch Step:1100, Proc Imgs: 110k ... Discriminator Loss: 1.1361... Generator Loss: 1.2034
# Epoch 2/2, Batch Step:1200, Proc Imgs: 120k ... Discriminator Loss: 0.7771... Generator Loss: 1.7712

# %%
batch_size = 100
z_dim = 100
learning_rate = 2e-4
beta1 = 0.35

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# input data_shape:  (60000, 28, 28, 1)
# input_real: (?, 28, 28, 1), input_z: (?, 100), lr: 0.0002
# Epoch 1/2, Batch Step:100, Proc Imgs: 10k ... Discriminator Loss: 1.2247... Generator Loss: 0.9917
# Epoch 1/2, Batch Step:200, Proc Imgs: 20k ... Discriminator Loss: 1.3542... Generator Loss: 0.7765
# Epoch 1/2, Batch Step:300, Proc Imgs: 30k ... Discriminator Loss: 1.3414... Generator Loss: 0.6918
# Epoch 1/2, Batch Step:400, Proc Imgs: 40k ... Discriminator Loss: 1.3097... Generator Loss: 0.9779
# Epoch 1/2, Batch Step:500, Proc Imgs: 50k ... Discriminator Loss: 1.1970... Generator Loss: 0.8590
# Epoch 1/2, Batch Step:600, Proc Imgs: 60k ... Discriminator Loss: 1.2554... Generator Loss: 0.6828
# Epoch 2/2, Batch Step:700, Proc Imgs: 70k ... Discriminator Loss: 1.3517... Generator Loss: 1.2802
# Epoch 2/2, Batch Step:800, Proc Imgs: 80k ... Discriminator Loss: 1.3152... Generator Loss: 1.0881
# Epoch 2/2, Batch Step:900, Proc Imgs: 90k ... Discriminator Loss: 1.3501... Generator Loss: 0.9962
# Epoch 2/2, Batch Step:1000, Proc Imgs: 100k ... Discriminator Loss: 1.3229... Generator Loss: 0.6989
# Epoch 2/2, Batch Step:1100, Proc Imgs: 110k ... Discriminator Loss: 1.2939... Generator Loss: 0.8807
# Epoch 2/2, Batch Step:1200, Proc Imgs: 120k ... Discriminator Loss: 1.3137... Generator Loss: 0.7199

# %%
batch_size = 50
z_dim = 100
learning_rate = 2e-4
beta1 = 0.2

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# input data_shape:  (60000, 28, 28, 1)
# input_real: (?, 28, 28, 1), input_z: (?, 100), lr: 0.0002
# Epoch 1/2, Batch Step:100, Proc Imgs: 5k ... Discriminator Loss: 1.3548... Generator Loss: 1.1848
# Epoch 1/2, Batch Step:200, Proc Imgs: 10k ... Discriminator Loss: 1.3370... Generator Loss: 0.6970
# Epoch 1/2, Batch Step:300, Proc Imgs: 15k ... Discriminator Loss: 1.3493... Generator Loss: 0.5918
# Epoch 1/2, Batch Step:400, Proc Imgs: 20k ... Discriminator Loss: 1.3188... Generator Loss: 1.1121
# Epoch 1/2, Batch Step:500, Proc Imgs: 25k ... Discriminator Loss: 1.3509... Generator Loss: 0.5840
# Epoch 1/2, Batch Step:600, Proc Imgs: 30k ... Discriminator Loss: 1.3917... Generator Loss: 0.8569
# Epoch 1/2, Batch Step:700, Proc Imgs: 35k ... Discriminator Loss: 1.3133... Generator Loss: 0.9202
# Epoch 1/2, Batch Step:800, Proc Imgs: 40k ... Discriminator Loss: 1.3306... Generator Loss: 0.9626
# Epoch 1/2, Batch Step:900, Proc Imgs: 45k ... Discriminator Loss: 1.3558... Generator Loss: 0.7497
# Epoch 1/2, Batch Step:1000, Proc Imgs: 50k ... Discriminator Loss: 1.3255... Generator Loss: 1.0063
# Epoch 1/2, Batch Step:1100, Proc Imgs: 55k ... Discriminator Loss: 1.2903... Generator Loss: 0.7951
# Epoch 1/2, Batch Step:1200, Proc Imgs: 60k ... Discriminator Loss: 1.3523... Generator Loss: 0.6739
# Epoch 2/2, Batch Step:1300, Proc Imgs: 65k ... Discriminator Loss: 1.3256... Generator Loss: 1.2037
# Epoch 2/2, Batch Step:1400, Proc Imgs: 70k ... Discriminator Loss: 1.2670... Generator Loss: 0.8456
# Epoch 2/2, Batch Step:1500, Proc Imgs: 75k ... Discriminator Loss: 1.3267... Generator Loss: 1.0360
# Epoch 2/2, Batch Step:1600, Proc Imgs: 80k ... Discriminator Loss: 1.3282... Generator Loss: 0.9737
# Epoch 2/2, Batch Step:1700, Proc Imgs: 85k ... Discriminator Loss: 1.2971... Generator Loss: 0.9912
# Epoch 2/2, Batch Step:1800, Proc Imgs: 90k ... Discriminator Loss: 1.2711... Generator Loss: 0.9600
# Epoch 2/2, Batch Step:1900, Proc Imgs: 95k ... Discriminator Loss: 1.2316... Generator Loss: 0.9052
# Epoch 2/2, Batch Step:2000, Proc Imgs: 100k ... Discriminator Loss: 1.2971... Generator Loss: 0.8838
# Epoch 2/2, Batch Step:2100, Proc Imgs: 105k ... Discriminator Loss: 1.3939... Generator Loss: 0.5184
# Epoch 2/2, Batch Step:2200, Proc Imgs: 110k ... Discriminator Loss: 1.2222... Generator Loss: 1.0854
# Epoch 2/2, Batch Step:2300, Proc Imgs: 115k ... Discriminator Loss: 1.2413... Generator Loss: 1.1085
# Epoch 2/2, Batch Step:2400, Proc Imgs: 120k ... Discriminator Loss: 1.1965... Generator Loss: 0.9271

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 50
z_dim = 100
learning_rate = 0.0002
beta1 = 0.2


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# input data_shape:  (202599, 28, 28, 3)
# input_real: (?, 28, 28, 3), input_z: (?, 100), lr: 0.0002
# Epoch 1/1, Batch Step:100, Proc Imgs: 5k ... Discriminator Loss: 1.2577... Generator Loss: 0.7608
# Epoch 1/1, Batch Step:200, Proc Imgs: 10k ... Discriminator Loss: 1.4500... Generator Loss: 0.4629
# Epoch 1/1, Batch Step:300, Proc Imgs: 15k ... Discriminator Loss: 0.8966... Generator Loss: 1.2595
# Epoch 1/1, Batch Step:400, Proc Imgs: 20k ... Discriminator Loss: 0.8162... Generator Loss: 1.3866
# Epoch 1/1, Batch Step:500, Proc Imgs: 25k ... Discriminator Loss: 0.7313... Generator Loss: 2.8556
# Epoch 1/1, Batch Step:600, Proc Imgs: 30k ... Discriminator Loss: 0.9073... Generator Loss: 2.0077
# Epoch 1/1, Batch Step:700, Proc Imgs: 35k ... Discriminator Loss: 0.9414... Generator Loss: 1.1922
# Epoch 1/1, Batch Step:800, Proc Imgs: 40k ... Discriminator Loss: 1.3451... Generator Loss: 0.8477
# Epoch 1/1, Batch Step:900, Proc Imgs: 45k ... Discriminator Loss: 1.0238... Generator Loss: 1.4641
# Epoch 1/1, Batch Step:1000, Proc Imgs: 50k ... Discriminator Loss: 0.9544... Generator Loss: 1.3561
# Epoch 1/1, Batch Step:1100, Proc Imgs: 55k ... Discriminator Loss: 0.6529... Generator Loss: 1.9737
# Epoch 1/1, Batch Step:1200, Proc Imgs: 60k ... Discriminator Loss: 0.8701... Generator Loss: 1.3392
# Epoch 1/1, Batch Step:1300, Proc Imgs: 65k ... Discriminator Loss: 0.9684... Generator Loss: 1.4928
# Epoch 1/1, Batch Step:1400, Proc Imgs: 70k ... Discriminator Loss: 1.0812... Generator Loss: 0.8743
# Epoch 1/1, Batch Step:1500, Proc Imgs: 75k ... Discriminator Loss: 0.7631... Generator Loss: 1.6278
# Epoch 1/1, Batch Step:1600, Proc Imgs: 80k ... Discriminator Loss: 1.8134... Generator Loss: 1.3295
# Epoch 1/1, Batch Step:1700, Proc Imgs: 85k ... Discriminator Loss: 0.7255... Generator Loss: 2.6439
# Epoch 1/1, Batch Step:1800, Proc Imgs: 90k ... Discriminator Loss: 0.9630... Generator Loss: 1.2530
# Epoch 1/1, Batch Step:1900, Proc Imgs: 95k ... Discriminator Loss: 0.7211... Generator Loss: 2.7660
# Epoch 1/1, Batch Step:2000, Proc Imgs: 100k ... Discriminator Loss: 0.7748... Generator Loss: 1.9369
# Epoch 1/1, Batch Step:2100, Proc Imgs: 105k ... Discriminator Loss: 1.0478... Generator Loss: 1.0357
# Epoch 1/1, Batch Step:2200, Proc Imgs: 110k ... Discriminator Loss: 0.9114... Generator Loss: 1.3625
# Epoch 1/1, Batch Step:2300, Proc Imgs: 115k ... Discriminator Loss: 0.9857... Generator Loss: 1.2729
# Epoch 1/1, Batch Step:2400, Proc Imgs: 120k ... Discriminator Loss: 0.9494... Generator Loss: 1.4217
# Epoch 1/1, Batch Step:2500, Proc Imgs: 125k ... Discriminator Loss: 0.9079... Generator Loss: 1.7711
# Epoch 1/1, Batch Step:2600, Proc Imgs: 130k ... Discriminator Loss: 0.9472... Generator Loss: 1.9792
# Epoch 1/1, Batch Step:2700, Proc Imgs: 135k ... Discriminator Loss: 0.9885... Generator Loss: 2.0031
# Epoch 1/1, Batch Step:2800, Proc Imgs: 140k ... Discriminator Loss: 1.3287... Generator Loss: 0.7592
# Epoch 1/1, Batch Step:2900, Proc Imgs: 145k ... Discriminator Loss: 0.9223... Generator Loss: 1.4766
# Epoch 1/1, Batch Step:3000, Proc Imgs: 150k ... Discriminator Loss: 1.1393... Generator Loss: 2.9124
# Epoch 1/1, Batch Step:3100, Proc Imgs: 155k ... Discriminator Loss: 1.0547... Generator Loss: 1.2170
# Epoch 1/1, Batch Step:3200, Proc Imgs: 160k ... Discriminator Loss: 0.9728... Generator Loss: 1.2262
# Epoch 1/1, Batch Step:3300, Proc Imgs: 165k ... Discriminator Loss: 0.6839... Generator Loss: 2.1780
# Epoch 1/1, Batch Step:3400, Proc Imgs: 170k ... Discriminator Loss: 0.9399... Generator Loss: 1.2211
# Epoch 1/1, Batch Step:3500, Proc Imgs: 175k ... Discriminator Loss: 0.7808... Generator Loss: 3.4747
# Epoch 1/1, Batch Step:3600, Proc Imgs: 180k ... Discriminator Loss: 0.9340... Generator Loss: 1.2359
# Epoch 1/1, Batch Step:3700, Proc Imgs: 185k ... Discriminator Loss: 0.8372... Generator Loss: 1.8950
# Epoch 1/1, Batch Step:3800, Proc Imgs: 190k ... Discriminator Loss: 0.9990... Generator Loss: 1.1908
# Epoch 1/1, Batch Step:3900, Proc Imgs: 195k ... Discriminator Loss: 1.0996... Generator Loss: 1.5109
# Epoch 1/1, Batch Step:4000, Proc Imgs: 200k ... Discriminator Loss: 0.7600... Generator Loss: 1.7355

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
