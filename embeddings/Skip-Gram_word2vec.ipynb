# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import collections, random
threshold = 1e-5
word_counts = collections.Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
print(len(int_words))
print(len(train_words))
# Out:
# 16680599
# 4627461

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    c = random.randint(1, window_size + 1)
    
    target = words[max(idx - c, 0):idx] + words[idx+1: idx+c+1]
    return list(set(target)) # uniq

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # in sampled_softmax_loss, weight dimension is [num_classes, dim], so z = W.x (not x.W here)
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6479 0.0886 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6092 0.0853 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5211 0.0888 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6117 0.0853 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5033 0.0857 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5395 0.0817 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5612 0.0824 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5288 0.0822 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4507 0.0825 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4576 0.0809 sec/batch
# Nearest to all: clovis, plugged, widely, beckham, smegma, internetwork, enjoy, alphorn,
# Nearest to while: caracalla, suites, swarming, ideals, technion, governmental, spellman, obscuring,
# Nearest to five: distinctly, nightly, tufts, archaeal, xxv, ludo, petacci, last,
# Nearest to at: kontor, zahn, ncv, bateson, keto, smp, she, nurtured,
# Nearest to between: metis, ircs, hazael, negotiations, restarts, youngman, transcending, pagoda,
# Nearest to can: napoleon, analytically, eighteen, bekenstein, fowl, ramanuja, ffing, calamities,
# Nearest to called: peterhead, sitka, cataria, interest, vespers, suitable, charnley, swindle,
# Nearest to zero: treasuries, stroessner, kay, hif, bassists, mansell, banque, quintilian,
# Nearest to institute: choy, scr, rouse, glens, adams, plaguing, vibe, conservatorium,
# Nearest to event: akin, aberdare, greys, lesund, kov, waltz, tempered, uphill,
# Nearest to heavy: radius, vanilla, brooklynites, frankness, progresses, sanatan, perineum, minivans,
# Nearest to smith: dame, buddhist, fulfill, welded, perrault, interlaced, exmoor, bak,
# Nearest to alternative: decompose, decibels, scotland, outlaws, ww, mirza, leakage, melodically,
# Nearest to taking: straus, mine, benjamins, iigs, shortages, stemming, displays, republik,
# Nearest to engineering: protestant, ve, lenin, arnulf, wrangling, sage, baez, pins,
# Nearest to road: interrupted, romney, wilmette, basing, drove, hedges, flagship, gerson,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4533 0.0823 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3853 0.0818 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3334 0.0818 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2324 0.0827 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1768 0.0824 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1302 0.0812 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1001 0.0819 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0543 0.0843 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9952 0.0822 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9631 0.0820 sec/batch
# Nearest to all: widely, plugged, enjoy, dangerous, beckham, ranging, clovis, house,
# Nearest to while: suites, others, ideals, governmental, nagasaki, actors, caracalla, advertising,
# Nearest to five: distinctly, nightly, last, discovery, even, tufts, raw, meant,
# Nearest to at: kontor, she, zahn, keto, castle, bateson, ncv, depended,
# Nearest to between: metis, negotiations, spatial, among, true, hazael, restarts, transcending,
# Nearest to can: napoleon, analytically, make, bekenstein, eighteen, physically, each, existed,
# Nearest to called: interest, say, fourth, suitable, zone, deserts, sitka, driving,
# Nearest to zero: treasuries, bassists, kay, stroessner, hif, stability, formalised, actively,
# Nearest to institute: scr, choy, glens, adams, units, fighting, rouse, reversed,
# Nearest to event: akin, followed, aberdare, tempered, kov, greys, apply, way,
# Nearest to heavy: radius, vanilla, progresses, brooklynites, support, frankness, impossible, generating,
# Nearest to smith: dame, buddhist, fulfill, welded, interlaced, gate, perrault, exmoor,
# Nearest to alternative: scotland, decompose, threats, leakage, ww, nfl, decibels, melodically,
# Nearest to taking: straus, mine, shortages, stemming, displays, iigs, withdraw, republik,
# Nearest to engineering: protestant, ve, lenin, mass, motown, arnulf, pins, sage,
# Nearest to road: interrupted, basing, romney, flagship, drove, wilmette, soldier, krause,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9330 0.0829 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9001 0.0838 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8680 0.0826 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8369 0.0825 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7941 0.0820 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8255 0.0827 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7843 0.0819 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8250 0.0817 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7835 0.0827 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7853 0.0849 sec/batch
# Nearest to all: plugged, ranging, clovis, widely, enjoy, smegma, dangerous, internetwork,
# Nearest to while: ideals, suites, spellman, advertising, caracalla, governmental, others, nagasaki,
# Nearest to five: distinctly, tufts, uel, xxv, nightly, discovery, reporting, last,
# Nearest to at: bateson, kontor, sudan, castle, zahn, keto, she, crystallography,
# Nearest to between: metis, negotiations, spatial, restarts, true, ganymede, among, hazael,
# Nearest to can: napoleon, analytically, binding, bekenstein, make, fowl, flores, each,
# Nearest to called: interest, suitable, say, ensues, fourth, collapsed, driving, sitka,
# Nearest to zero: bassists, treasuries, stroessner, formalised, aerobic, hif, banque, malevich,
# Nearest to institute: choy, scr, glens, rouse, vibe, adams, wastes, plaguing,
# Nearest to event: akin, followed, aberdare, kov, tempered, tame, unpaved, waltz,
# Nearest to heavy: radius, progresses, vanilla, frankness, brooklynites, impossible, generating, unaware,
# Nearest to smith: dame, buddhist, fulfill, interlaced, welded, perrault, gate, avril,
# Nearest to alternative: scotland, decompose, ww, leakage, outlaws, melodically, decibels, taoiseach,
# Nearest to taking: straus, stemming, mine, shortages, displays, republik, withdraw, iigs,
# Nearest to engineering: protestant, ve, lenin, pins, motown, mass, arnulf, focused,
# Nearest to road: interrupted, drove, romney, flagship, basing, silesia, wilmette, wells,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7822 0.0821 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7412 0.0818 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7124 0.0813 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7096 0.0815 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7250 0.0816 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6898 0.0836 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6932 0.0826 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7369 0.0833 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6965 0.0825 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6608 0.0838 sec/batch
# Nearest to all: internetwork, plugged, forgiveness, clovis, smegma, ranging, beckham, dangerous,
# Nearest to while: ideals, suites, caracalla, spellman, advertising, governmental, others, nagasaki,
# Nearest to five: nine, uel, tufts, zero, xxv, two, ayyash, one,
# Nearest to at: kontor, bateson, keto, crystallography, castle, sudan, zahn, she,
# Nearest to between: metis, negotiations, hazael, ircs, restarts, youngman, paideia, ganymede,
# Nearest to can: analytically, fowl, binding, napoleon, will, each, involves, bekenstein,
# Nearest to called: interest, suitable, ensues, zone, sitka, collapsed, vespers, twisters,
# Nearest to zero: bassists, two, eight, five, stroessner, formalised, treasuries, seven,
# Nearest to institute: scr, choy, vibe, rouse, glens, adams, plaguing, bainimarama,
# Nearest to event: akin, aberdare, followed, tempered, kov, beginners, conclave, greys,
# Nearest to heavy: radius, frankness, vanilla, progresses, brooklynites, torpedo, generating, impossible,
# Nearest to smith: dame, buddhist, fulfill, perrault, welded, interlaced, avril, gate,
# Nearest to alternative: decompose, outlaws, ww, decibels, melodically, scotland, leakage, taoiseach,
# Nearest to taking: straus, stemming, mine, republik, withdraw, iigs, shortages, displays,
# Nearest to engineering: protestant, ve, pins, lenin, pointers, arnulf, baez, motown,
# Nearest to road: interrupted, drove, romney, flagship, silesia, basing, wilmette, hedges,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6528 0.0846 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6952 0.0818 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6357 0.0824 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6392 0.0825 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6480 0.0830 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6166 0.0810 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5986 0.0629 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5606 0.0820 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5210 0.0827 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5154 0.0817 sec/batch
# Nearest to all: forgiveness, internetwork, clovis, plugged, smegma, ranging, dangerous, morphisms,
# Nearest to while: ideals, caracalla, suites, spellman, advertising, ju, others, governmental,
# Nearest to five: two, nine, zero, uel, tufts, one, lucie, architect,
# Nearest to at: keto, kontor, crystallography, bateson, castle, sudan, unawares, treasures,
# Nearest to between: ircs, paideia, disapproved, hazael, metis, restarts, youngman, spatial,
# Nearest to can: will, analytically, fowl, if, binding, such, involves, this,
# Nearest to called: suitable, interest, say, sitka, ensues, vespers, twisters, zone,
# Nearest to zero: two, eight, five, bassists, stroessner, six, seven, four,
# Nearest to institute: scr, choy, vibe, rouse, glens, conservatorium, bainimarama, unspectacular,
# Nearest to event: akin, aberdare, followed, uphill, conclave, kov, greys, beginners,
# Nearest to heavy: vanilla, radius, frankness, brooklynites, progresses, torpedo, wagering, impossible,
# Nearest to smith: dame, perrault, buddhist, fulfill, murdoch, interlaced, savior, welded,
# Nearest to alternative: decompose, decibels, melodically, outlaws, leakage, ww, mirza, electric,
# Nearest to taking: straus, stemming, mine, republik, displays, benjamins, withdraw, shortages,
# Nearest to engineering: pins, pointers, arnulf, protestant, ve, motown, baez, lenin,
# Nearest to road: interrupted, romney, silesia, drove, flagship, gerson, basing, michigan,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4972 0.0826 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5254 0.0819 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4808 0.0857 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5393 0.0821 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5117 0.0824 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4905 0.0833 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4634 0.0818 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4012 0.0825 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4249 0.0839 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4332 0.0834 sec/batch
# Nearest to all: smegma, forgiveness, internetwork, plugged, clovis, dangerous, morphisms, ranging,
# Nearest to while: ideals, suites, caracalla, advertising, spellman, weak, others, ju,
# Nearest to five: two, zero, uel, nine, tufts, population, one, lucie,
# Nearest to at: keto, kontor, crystallography, castle, bateson, treasures, unawares, eastbourne,
# Nearest to between: paideia, ircs, youngman, disapproved, metis, spatial, restarts, plath,
# Nearest to can: will, analytically, fowl, if, involves, binding, dimensional, such,
# Nearest to called: suitable, interest, is, zone, ensues, tours, rotated, tuples,
# Nearest to zero: two, eight, five, population, bassists, four, six, stroessner,
# Nearest to institute: scr, choy, vibe, shanks, glens, education, rouse, bainimarama,
# Nearest to event: akin, aberdare, conclave, uphill, followed, greys, tempered, quarrel,
# Nearest to heavy: frankness, radius, vanilla, progresses, brooklynites, torpedo, wagering, street,
# Nearest to smith: dame, perrault, buddhist, savior, murdoch, fulfill, exmoor, greenpeace,
# Nearest to alternative: decibels, decompose, mirza, melodically, electric, leakage, florin, outlaws,
# Nearest to taking: straus, stemming, mine, republik, benjamins, withdraw, shortages, course,
# Nearest to engineering: pins, pointers, arnulf, motown, protestant, cr, sage, baez,
# Nearest to road: romney, interrupted, michigan, flagship, tradesmen, silesia, rodrigo, basing,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4561 0.0833 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4282 0.0816 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4463 0.0829 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3917 0.0817 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3992 0.0818 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4582 0.0814 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3780 0.0827 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3907 0.0809 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4080 0.0811 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4085 0.0816 sec/batch
# Nearest to all: smegma, forgiveness, internetwork, plugged, opinions, in, morphisms, nva,
# Nearest to while: ideals, caracalla, suites, advertising, weak, spellman, cancellations, harmless,
# Nearest to five: two, zero, one, nine, uel, nightly, ayyash, tufts,
# Nearest to at: keto, unawares, castle, kontor, aqualung, crystallography, bateson, alexandr,
# Nearest to between: paideia, spatial, disapproved, youngman, ircs, negotiations, metis, hurst,
# Nearest to can: will, binding, analytically, dimensional, fowl, physically, make, diodes,
# Nearest to called: suitable, interest, is, rotated, zone, tours, gneiss, constituents,
# Nearest to zero: two, eight, five, four, six, stroessner, bassists, utc,
# Nearest to institute: scr, shanks, education, vibe, choy, glens, nem, adams,
# Nearest to event: akin, aberdare, conclave, uphill, greys, followed, kov, whaler,
# Nearest to heavy: frankness, vanilla, radius, progresses, torpedo, moraines, brooklynites, wagering,
# Nearest to smith: dame, perrault, murdoch, savior, greenpeace, buddhist, avril, iqaluit,
# Nearest to alternative: decibels, decompose, electric, melodically, florin, leakage, mirza, ww,
# Nearest to taking: straus, stemming, mine, republik, benjamins, course, withdraw, displays,
# Nearest to engineering: pins, arnulf, pointers, subsection, motown, cr, uncreated, subscript,
# Nearest to road: interrupted, michigan, romney, flagship, tradesmen, fidesz, locomotives, silesia,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3941 0.0837 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3964 0.0834 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3819 0.0821 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3743 0.0817 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4293 0.0820 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3644 0.0807 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3965 0.0815 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3989 0.0817 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3360 0.0814 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3668 0.0814 sec/batch
# Nearest to all: smegma, forgiveness, opinions, disiyyah, morphisms, in, nva, clovis,
# Nearest to while: ideals, caracalla, suites, advertising, weak, spellman, blunder, cancellations,
# Nearest to five: two, zero, one, nine, uel, six, expenditure, four,
# Nearest to at: keto, unawares, eastbourne, bateson, alexandr, castle, piqued, treasures,
# Nearest to between: disapproved, ircs, youngman, paideia, spatial, hgp, negotiations, hundreds,
# Nearest to can: will, binding, analytically, dimensional, fowl, diodes, physically, visually,
# Nearest to called: interest, gneiss, suitable, cataria, is, tours, curran, vespers,
# Nearest to zero: two, five, eight, four, six, population, stroessner, one,
# Nearest to institute: education, shanks, scr, vibe, choy, glens, nem, adams,
# Nearest to event: akin, uphill, aberdare, conclave, vouchers, greys, quarrel, whaler,
# Nearest to heavy: frankness, radius, progresses, vanilla, torpedo, moraines, street, brooklynites,
# Nearest to smith: dame, perrault, murdoch, savior, greenberg, greenpeace, avril, brady,
# Nearest to alternative: decibels, decompose, melodically, leakage, electric, florin, mirza, ww,
# Nearest to taking: stemming, republik, benjamins, straus, mine, course, withdraw, displays,
# Nearest to engineering: pins, pointers, arnulf, subsection, subscript, motown, cr, uncreated,
# Nearest to road: interrupted, michigan, romney, flagship, fidesz, drove, tunnels, tradesmen,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3427 0.0851 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3091 0.0839 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3607 0.0822 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3930 0.0826 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3725 0.0838 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2991 0.0832 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2995 0.0813 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3648 0.0822 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2513 0.0827 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3219 0.0841 sec/batch
# Nearest to all: smegma, forgiveness, morphisms, in, disiyyah, nva, muted, yeomen,
# Nearest to while: ideals, caracalla, cancellations, advertising, suites, blunder, weak, improvisations,
# Nearest to five: two, zero, one, nine, six, four, three, uel,
# Nearest to at: unawares, eastbourne, keto, bateson, alexandr, castle, piqued, grammy,
# Nearest to between: disapproved, ircs, youngman, negotiations, paideia, bpm, spatial, hundreds,
# Nearest to can: will, analytically, binding, fowl, dimensional, diodes, ie, orgasm,
# Nearest to called: interest, is, suitable, curran, gneiss, vespers, tours, rb,
# Nearest to zero: two, five, four, eight, six, one, population, stroessner,
# Nearest to institute: education, shanks, scr, vibe, glens, sigur, choy, nem,
# Nearest to event: akin, uphill, aberdare, vouchers, conclave, greys, quarrel, whaler,
# Nearest to heavy: frankness, radius, progresses, vanilla, torpedo, moraines, brooklynites, street,
# Nearest to smith: perrault, dame, murdoch, savior, greenberg, greenpeace, exmoor, anthropologist,
# Nearest to alternative: decibels, decompose, melodically, florin, mirza, leakage, electric, ww,
# Nearest to taking: republik, stemming, straus, benjamins, mine, course, withdraw, nurturing,
# Nearest to engineering: pins, pointers, arnulf, subsection, subscript, uncreated, cr, motown,
# Nearest to road: interrupted, michigan, flagship, romney, drove, tunnels, fidesz, locomotives,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3130 0.0830 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3027 0.0819 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3304 0.0389 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2494 0.0831 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2214 0.0820 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2468 0.0820 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2008 0.0826 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2190 0.0816 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2183 0.0816 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2203 0.0832 sec/batch
# Nearest to all: smegma, forgiveness, nutation, aalborg, morphisms, restricting, ll, internetwork,
# Nearest to while: ideals, caracalla, suites, cancellations, advertising, weak, blunder, improvisations,
# Nearest to five: two, zero, one, nine, six, three, four, eight,
# Nearest to at: eastbourne, unawares, keto, bateson, castle, peaked, alexandr, nuages,
# Nearest to between: disapproved, youngman, ircs, bpm, spatial, paideia, ba, flavio,
# Nearest to can: will, analytically, orgasm, fowl, binding, diodes, kirin, calibration,
# Nearest to called: suitable, is, tours, zone, vespers, shaped, salar, interest,
# Nearest to zero: two, five, four, eight, six, one, population, seven,
# Nearest to institute: education, shanks, institution, scr, vibe, nem, glens, choy,
# Nearest to event: akin, conclave, vouchers, uphill, quarrel, aberdare, greys, unarmed,
# Nearest to heavy: frankness, vanilla, progresses, radius, torpedo, moraines, brooklynites, street,
# Nearest to smith: perrault, dame, murdoch, exmoor, greenpeace, savior, greenberg, spencer,
# Nearest to alternative: decibels, florin, mirza, decompose, melodically, leakage, editorship, electric,
# Nearest to taking: stemming, republik, mine, benjamins, course, straus, withdraw, iigs,
# Nearest to engineering: pins, arnulf, pointers, subsection, cr, sage, vinge, economics,
# Nearest to road: michigan, interrupted, drove, tunnels, flagship, railway, locomotives, romney,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2519 0.0840 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2489 0.0814 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2301 0.0818 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1521 0.0832 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1797 0.0823 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1700 0.0823 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1797 0.0824 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1816 0.0828 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2060 0.0830 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1785 0.0814 sec/batch
# Nearest to all: smegma, ll, forgiveness, morphisms, nutation, in, restricting, muted,
# Nearest to while: ideals, suites, cancellations, advertising, caracalla, weak, blunder, obscuring,
# Nearest to five: two, zero, one, nine, six, four, three, eight,
# Nearest to at: eastbourne, unawares, nuages, keto, castle, peaked, treasures, piqued,
# Nearest to between: spatial, youngman, ircs, disapproved, bpm, paideia, flavio, metis,
# Nearest to can: will, analytically, orgasm, diodes, binding, kirin, fowl, calibration,
# Nearest to called: shaped, tours, suitable, zone, salar, thinner, sand, curran,
# Nearest to zero: two, five, four, eight, one, six, population, seven,
# Nearest to institute: education, shanks, institution, university, graduate, scr, vibe, stanford,
# Nearest to event: akin, uphill, aberdare, vouchers, conclave, greys, as, necklaces,
# Nearest to heavy: frankness, torpedo, progresses, vanilla, moraines, radius, grinder, minivans,
# Nearest to smith: perrault, murdoch, dame, greenpeace, exmoor, savior, greenberg, avril,
# Nearest to alternative: decibels, florin, mirza, decompose, leakage, melodically, search, royalties,
# Nearest to taking: course, benjamins, mine, republik, stemming, straus, withdraw, iigs,
# Nearest to engineering: pins, subsection, arnulf, pointers, economics, vinge, sage, cr,
# Nearest to road: michigan, interrupted, tunnels, drove, railway, romney, locomotives, adhemar,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1852 0.0827 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2308 0.0842 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1857 0.0822 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1552 0.0823 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2011 0.0827 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2374 0.0837 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2249 0.0831 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1959 0.0831 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1513 0.0818 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1757 0.0825 sec/batch
# Nearest to all: smegma, forgiveness, ll, morphisms, in, za, nutation, aalborg,
# Nearest to while: ideals, suites, blunder, cancellations, advertising, weak, caracalla, obscuring,
# Nearest to five: two, zero, one, nine, six, four, three, eight,
# Nearest to at: eastbourne, bateson, nuages, piqued, unawares, verant, keto, crystallography,
# Nearest to between: spatial, disapproved, youngman, bpm, ircs, paideia, transcending, persia,
# Nearest to can: will, analytically, diodes, orgasm, kirin, binding, fowl, if,
# Nearest to called: tours, salar, vespers, shaped, celtics, curran, aspirate, suitable,
# Nearest to zero: two, five, four, eight, one, six, population, rate,
# Nearest to institute: education, shanks, institution, university, graduate, scr, vibe, stanford,
# Nearest to event: akin, uphill, as, aberdare, unarmed, conclave, vouchers, quarrel,
# Nearest to heavy: frankness, progresses, vanilla, moraines, radius, torpedo, minivans, brooklynites,
# Nearest to smith: perrault, murdoch, dame, exmoor, greenpeace, savior, greenberg, doak,
# Nearest to alternative: decibels, florin, decompose, mirza, leakage, melodically, royalties, electric,
# Nearest to taking: course, republik, benjamins, stemming, mine, withdraw, straus, shortages,
# Nearest to engineering: pins, economics, subsection, pointers, arnulf, protestant, vinge, uncreated,
# Nearest to road: michigan, tunnels, railway, interrupted, drove, hedges, romney, adhemar,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2362 0.0830 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1813 0.0821 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1784 0.0827 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2057 0.0821 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1748 0.0820 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1532 0.0824 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1839 0.0831 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1326 0.0825 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2316 0.0822 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2114 0.0828 sec/batch
# Nearest to all: smegma, ll, forgiveness, morphisms, in, aalborg, za, disiyyah,
# Nearest to while: ideals, blunder, cancellations, suites, caracalla, weak, advertising, obscuring,
# Nearest to five: two, zero, one, six, nine, three, four, eight,
# Nearest to at: eastbourne, unawares, woman, bateson, nuages, verant, piqued, peaked,
# Nearest to between: youngman, disapproved, ircs, spatial, bpm, flavio, paideia, cerezo,
# Nearest to can: will, analytically, binding, orgasm, kirin, ffing, fowl, diodes,
# Nearest to called: tours, celtics, vespers, zone, curran, distrusted, interest, salar,
# Nearest to zero: two, five, four, one, eight, six, seven, three,
# Nearest to institute: education, institution, shanks, graduate, university, vibe, scr, stanford,
# Nearest to event: akin, as, quarrel, uphill, aberdare, unarmed, conclave, necklaces,
# Nearest to heavy: vanilla, progresses, moraines, frankness, minivans, grinder, brooklynites, radius,
# Nearest to smith: perrault, murdoch, dame, exmoor, greenpeace, savior, doak, iqaluit,
# Nearest to alternative: decibels, florin, mirza, royalties, decompose, leakage, melodically, andree,
# Nearest to taking: course, benjamins, republik, stemming, mine, withdraw, straus, iigs,
# Nearest to engineering: pins, economics, subsection, arnulf, pointers, protestant, sage, vinge,
# Nearest to road: michigan, tunnels, interrupted, railway, drove, hedges, romney, adhemar,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2559 0.0839 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1603 0.0848 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1162 0.0820 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1869 0.0825 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0419 0.0824 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1646 0.0822 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1643 0.0817 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1619 0.0823 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1821 0.0162 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1225 0.0814 sec/batch
# Nearest to all: ll, smegma, morphisms, forgiveness, restricting, aalborg, za, nutation,
# Nearest to while: ideals, cancellations, blunder, suites, caracalla, weak, advertising, improvisations,
# Nearest to five: two, zero, one, six, three, nine, four, eight,
# Nearest to at: eastbourne, unawares, nuages, crystallography, piqued, woman, verant, sabbats,
# Nearest to between: spatial, disapproved, ircs, youngman, flavio, bpm, herodotus, cerezo,
# Nearest to can: will, orgasm, analytically, indirection, binding, kirin, ulcers, ffing,
# Nearest to called: function, rb, zone, aspirate, vespers, rotated, suitable, interest,
# Nearest to zero: two, five, four, one, eight, six, three, seven,
# Nearest to institute: education, institution, graduate, shanks, university, vibe, stanford, scr,
# Nearest to event: akin, as, quarrel, unarmed, uphill, vouchers, aberdare, necklaces,
# Nearest to heavy: progresses, moraines, vanilla, frankness, minivans, grinder, torpedo, brooklynites,
# Nearest to smith: perrault, murdoch, exmoor, dame, greenpeace, doak, bak, pathfinder,
# Nearest to alternative: decibels, florin, royalties, leakage, toolbar, mirza, decompose, keywords,
# Nearest to taking: benjamins, course, republik, mine, stemming, withdraw, straus, iigs,
# Nearest to engineering: pins, economics, protestant, pointers, subsection, arnulf, healthcare, unavailable,
# Nearest to road: michigan, tunnels, railway, drove, romney, hedges, interrupted, adhemar,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0798 0.0835 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0861 0.0833 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0971 0.0820 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0703 0.0816 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0836 0.0815 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0182 0.0825 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1113 0.0824 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1094 0.0833 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1484 0.0827 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0275 0.0829 sec/batch
# Nearest to all: ll, smegma, morphisms, restricting, forgiveness, in, nutation, infractions,
# Nearest to while: cancellations, suites, ideals, blunder, weak, caracalla, quickly, improvisations,
# Nearest to five: two, zero, one, six, three, four, nine, eight,
# Nearest to at: eastbourne, unawares, afloat, crystallography, nuages, flatly, verant, peaked,
# Nearest to between: spatial, youngman, ircs, bpm, disapproved, flavio, ba, persia,
# Nearest to can: will, analytically, orgasm, kirin, indirection, fowl, binding, ulcers,
# Nearest to called: zone, tours, celtics, is, shaped, dogwood, suitable, thinner,
# Nearest to zero: two, five, four, one, eight, six, three, rate,
# Nearest to institute: education, institution, graduate, shanks, university, stanford, vibe, scr,
# Nearest to event: akin, as, quarrel, unarmed, conclave, vouchers, uphill, necklaces,
# Nearest to heavy: moraines, minivans, progresses, frankness, grinder, vanilla, torpedo, mallard,
# Nearest to smith: perrault, murdoch, exmoor, greenpeace, dame, doak, interlaced, iqaluit,
# Nearest to alternative: decibels, florin, royalties, mirza, leakage, toolbar, decompose, andree,
# Nearest to taking: course, benjamins, stemming, republik, mine, withdraw, impairment, shortages,
# Nearest to engineering: pins, economics, pointers, enrollment, vinge, sage, arnulf, protestant,
# Nearest to road: michigan, tunnels, railway, drove, interrupted, adhemar, hedges, municipal,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0526 0.0846 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0484 0.0832 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0169 0.0853 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0743 0.0833 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0676 0.0831 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0563 0.0834 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0601 0.0845 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1372 0.0835 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0552 0.0833 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0577 0.0832 sec/batch
# Nearest to all: ll, smegma, morphisms, restricting, forgiveness, in, infractions, elucidating,
# Nearest to while: cancellations, ideals, suites, blunder, weak, quickly, attained, obscuring,
# Nearest to five: zero, two, one, six, four, nine, three, eight,
# Nearest to at: eastbourne, nuages, unawares, crystallography, flatly, verant, pobedonostsev, of,
# Nearest to between: spatial, ircs, bpm, youngman, flavio, beja, disapproved, hurst,
# Nearest to can: will, analytically, orgasm, binding, radix, for, indirection, kirin,
# Nearest to called: zone, tours, suitable, shaped, whose, aspirate, function, celtics,
# Nearest to zero: two, five, four, one, eight, six, seven, three,
# Nearest to institute: education, institution, graduate, university, shanks, stanford, vibe, school,
# Nearest to event: akin, as, necklaces, uphill, quarrel, unarmed, defibrillation, conclave,
# Nearest to heavy: moraines, minivans, progresses, vanilla, grinder, frankness, torpedo, shipboard,
# Nearest to smith: perrault, murdoch, exmoor, greenpeace, doak, bak, faith, dame,
# Nearest to alternative: decibels, florin, mirza, royalties, leakage, toolbar, andree, editorship,
# Nearest to taking: course, benjamins, stemming, mine, republik, impairment, straus, withdraw,
# Nearest to engineering: pins, economics, humanities, enrollment, protestant, sage, subsection, motorsport,
# Nearest to road: tunnels, railway, michigan, drove, hedges, romney, interrupted, adhemar,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0782 0.0857 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0904 0.0830 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1030 0.0832 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0536 0.0839 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0825 0.0854 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0593 0.0844 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0920 0.0846 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0700 0.0839 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0784 0.0840 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0849 0.0833 sec/batch
# Nearest to all: ll, smegma, morphisms, restricting, infractions, forgiveness, in, elucidating,
# Nearest to while: cancellations, ideals, blunder, suites, weak, sundial, caracalla, quickly,
# Nearest to five: zero, two, one, six, three, four, nine, eight,
# Nearest to at: eastbourne, nuages, unawares, in, of, pobedonostsev, crystallography, piqued,
# Nearest to between: spatial, youngman, beja, ircs, bpm, arab, intensification, flavio,
# Nearest to can: will, analytically, binding, indirection, orgasm, jawed, ffing, weaves,
# Nearest to called: zone, tours, celtics, whose, distrusted, combats, aspirate, twisters,
# Nearest to zero: two, five, four, one, eight, six, seven, three,
# Nearest to institute: education, institution, graduate, shanks, university, scr, vibe, stanford,
# Nearest to event: akin, as, uphill, quarrel, necklaces, unarmed, aberdare, vouchers,
# Nearest to heavy: minivans, moraines, vanilla, progresses, grinder, frankness, shipboard, brooklynites,
# Nearest to smith: perrault, murdoch, exmoor, greenpeace, dame, doak, bak, interlaced,
# Nearest to alternative: decibels, florin, royalties, leakage, mirza, toolbar, decompose, vorticity,
# Nearest to taking: course, benjamins, stemming, republik, mine, alternates, impairment, archie,
# Nearest to engineering: pins, humanities, economics, protestant, enrollment, motorsport, sage, healthcare,
# Nearest to road: railway, tunnels, romney, drove, hedges, interrupted, michigan, howto,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0626 0.0858 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0257 0.0843 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0304 0.0835 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0703 0.0838 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0841 0.0842 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1379 0.0841 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1323 0.0835 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0738 0.0835 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0814 0.0846 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0557 0.0843 sec/batch
# Nearest to all: ll, smegma, morphisms, in, forgiveness, acknowledgment, restricting, infractions,
# Nearest to while: cancellations, ideals, blunder, suites, weak, quickly, attained, improvisations,
# Nearest to five: zero, two, one, six, three, four, nine, seven,
# Nearest to at: eastbourne, in, nuages, unawares, of, crystallography, he, woman,
# Nearest to between: youngman, spatial, ircs, intensification, bpm, flavio, whichever, beja,
# Nearest to can: will, analytically, radix, indirection, orgasm, if, for, weaves,
# Nearest to called: zone, combats, tours, dogwood, celtics, aspirate, function, distrusted,
# Nearest to zero: two, five, one, four, eight, six, seven, three,
# Nearest to institute: education, institution, graduate, shanks, university, scr, vibe, stanford,
# Nearest to event: akin, as, quarrel, uphill, vouchers, conclave, unarmed, break,
# Nearest to heavy: minivans, moraines, progresses, grinder, vanilla, frankness, reprisals, insurgencies,
# Nearest to smith: perrault, exmoor, murdoch, greenpeace, doak, faith, discordant, bak,
# Nearest to alternative: decibels, florin, mirza, toolbar, royalties, leakage, andree, melodically,
# Nearest to taking: benjamins, course, stemming, republik, mine, alternates, manco, archie,
# Nearest to engineering: pins, protestant, humanities, enrollment, motorsport, sage, vinge, economics,
# Nearest to road: railway, tunnels, romney, howto, hedges, michigan, drove, interrupted,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0079 0.0840 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0482 0.0832 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0611 0.0838 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0370 0.0829 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0843 0.0838 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0433 0.0792 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0165 0.0835 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0238 0.0830 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0351 0.0834 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9909 0.0831 sec/batch
# Nearest to all: ll, smegma, morphisms, restricting, in, infractions, judaism, forgiveness,
# Nearest to while: cancellations, ideals, suites, weak, blunder, quickly, improvisations, attained,
# Nearest to five: two, zero, one, six, three, four, nine, seven,
# Nearest to at: eastbourne, in, of, crystallography, unawares, nuages, he, treatise,
# Nearest to between: spatial, bpm, ircs, youngman, whichever, disapproved, intensification, beja,
# Nearest to can: will, orgasm, ulcers, indirection, analytically, if, binding, jawed,
# Nearest to called: dogwood, zone, function, combats, cataria, distrusted, aspirate, crispy,
# Nearest to zero: two, five, four, one, eight, six, seven, three,
# Nearest to institute: education, institution, graduate, shanks, university, stanford, scr, school,
# Nearest to event: akin, quarrel, conclave, uphill, as, vouchers, break, aberdare,
# Nearest to heavy: moraines, minivans, progresses, grinder, vanilla, frankness, shipboard, mallard,
# Nearest to smith: perrault, exmoor, murdoch, greenpeace, doak, footballer, interlaced, dame,
# Nearest to alternative: decibels, florin, toolbar, mirza, leakage, royalties, andree, roch,
# Nearest to taking: course, benjamins, republik, stemming, manco, mine, alternates, impairment,
# Nearest to engineering: pins, humanities, protestant, motorsport, enrollment, economics, sage, architectural,
# Nearest to road: railway, tunnels, michigan, romney, drove, hedges, howto, roads,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0097 0.0842 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9470 0.0844 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0495 0.0842 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0359 0.0845 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0429 0.0852 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0075 0.0835 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9365 0.0836 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9839 0.0837 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9719 0.0829 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9870 0.0836 sec/batch
# Nearest to all: ll, morphisms, smegma, restricting, infractions, in, nonempty, forgiveness,
# Nearest to while: cancellations, ideals, suites, weak, quickly, blunder, sundial, obscuring,
# Nearest to five: zero, two, one, six, four, three, nine, eight,
# Nearest to at: in, of, eastbourne, crystallography, unawares, nuages, kitchens, treatise,
# Nearest to between: spatial, ircs, bpm, hurst, intensification, flavio, beja, lindow,
# Nearest to can: will, for, if, orgasm, ulcers, analytically, indirection, this,
# Nearest to called: zone, whose, dogwood, function, celtics, is, kind, aspirate,
# Nearest to zero: two, five, four, one, eight, six, three, seven,
# Nearest to institute: education, graduate, institution, university, shanks, school, scr, conservatorium,
# Nearest to event: akin, as, uphill, quarrel, conclave, vouchers, aberdare, events,
# Nearest to heavy: minivans, moraines, progresses, grinder, vanilla, frankness, shipboard, reprisals,
# Nearest to smith: exmoor, perrault, murdoch, greenpeace, faith, doak, footballer, dempsey,
# Nearest to alternative: florin, decibels, mirza, royalties, toolbar, editorship, andree, roch,
# Nearest to taking: course, benjamins, republik, stemming, manco, archie, alternates, mine,
# Nearest to engineering: pins, humanities, protestant, sage, enrollment, motorsport, economics, architectural,
# Nearest to road: tunnels, railway, michigan, romney, drove, roads, hedges, howto,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0216 0.0850 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0245 0.0837 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9706 0.0852 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0234 0.0829 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0663 0.0839 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9529 0.0833 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0149 0.0849 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0176 0.0844 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0150 0.0839 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0067 0.0831 sec/batch
# Nearest to all: ll, in, infractions, smegma, morphisms, restricting, forgiveness, crowd,
# Nearest to while: cancellations, ideals, suites, weak, blunder, sundial, quickly, obscuring,
# Nearest to five: zero, two, one, six, three, four, nine, eight,
# Nearest to at: in, eastbourne, of, nuages, crystallography, unawares, piqued, sabbats,
# Nearest to between: spatial, bpm, hurst, ircs, intensification, caatinga, lindow, beja,
# Nearest to can: will, if, for, this, analytically, bot, indirection, orgasm,
# Nearest to called: function, celtics, zone, whose, kind, combats, diffeomorphic, aspirate,
# Nearest to zero: five, two, one, four, eight, six, three, seven,
# Nearest to institute: education, graduate, institution, shanks, university, scr, vibe, conservatorium,
# Nearest to event: akin, as, events, uphill, necklaces, aberdare, quarrel, vouchers,
# Nearest to heavy: moraines, minivans, progresses, shipboard, grinder, vanilla, frankness, reprisals,
# Nearest to smith: exmoor, greenpeace, murdoch, perrault, footballer, doak, dempsey, discordant,
# Nearest to alternative: decibels, florin, royalties, mirza, toolbar, vorticity, electric, roch,
# Nearest to taking: course, benjamins, republik, stemming, archie, impairment, alternates, manipulations,
# Nearest to engineering: pins, humanities, enrollment, protestant, motorsport, economics, sage, vinge,
# Nearest to road: tunnels, romney, railway, michigan, drove, motorway, roads, howto,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0096 0.0844 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0090 0.0830 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9799 0.0825 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0111 0.0833 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0188 0.0844 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0149 0.0843 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0165 0.0840 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9790 0.0846 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9761 0.0835 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0868 0.0839 sec/batch
# Nearest to all: ll, in, morphisms, infractions, smegma, nonempty, restricting, judaism,
# Nearest to while: cancellations, ideals, weak, blunder, suites, quickly, sundial, others,
# Nearest to five: zero, two, one, six, three, four, nine, eight,
# Nearest to at: eastbourne, in, of, nuages, spee, unawares, nearby, piqued,
# Nearest to between: intensification, arab, beja, spatial, caatinga, ircs, lindow, the,
# Nearest to can: will, if, this, for, analytically, radix, ulcers, indirection,
# Nearest to called: function, kind, combats, zone, cataria, diffeomorphic, celtics, microorganisms,
# Nearest to zero: two, five, one, four, eight, six, three, seven,
# Nearest to institute: education, graduate, institution, shanks, university, scr, vibe, conservatorium,
# Nearest to event: akin, as, events, aberdare, quarrel, uphill, necklaces, vouchers,
# Nearest to heavy: minivans, moraines, grinder, progresses, shipboard, vanilla, tso, frankness,
# Nearest to smith: exmoor, perrault, greenpeace, murdoch, footballer, doak, dempsey, discordant,
# Nearest to alternative: decibels, florin, toolbar, mirza, vorticity, royalties, northrop, leakage,
# Nearest to taking: course, benjamins, republik, stemming, manco, alternates, impairment, shortages,
# Nearest to engineering: pins, humanities, enrollment, protestant, economics, motorsport, sage, meigs,
# Nearest to road: tunnels, railway, romney, michigan, roads, drove, motorway, howto,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9983 0.0845 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1045 0.0829 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0338 0.0828 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0820 0.0832 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9962 0.0817 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9352 0.0818 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9923 0.0817 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9434 0.0829 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9906 0.0815 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9920 0.0822 sec/batch
# Nearest to all: morphisms, ll, in, infractions, smegma, nonempty, converse, judaism,
# Nearest to while: cancellations, ideals, weak, quickly, suites, blunder, well, sixteen,
# Nearest to five: zero, two, one, six, three, four, nine, eight,
# Nearest to at: in, eastbourne, of, nuages, unawares, crystallography, woman, schematics,
# ...
# Nearest to road: tunnels, motorway, drove, railway, roads, revue, nontrivial, howto,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.9047 0.0880 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7996 0.0890 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8448 0.0876 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8417 0.0875 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8270 0.0881 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8799 0.0885 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8820 0.0875 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8492 0.0886 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8929 0.0893 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9211 0.0884 sec/batch
# Nearest to all: in, and, thus, the, with, are, for, two,
# Nearest to while: it, in, cancellations, have, and, well, weak, others,
# Nearest to five: zero, two, one, four, six, three, eight, nine,
# Nearest to at: in, of, to, an, he, eastbourne, a, the,
# Nearest to between: the, bpm, of, beja, a, and, whichever, repulsed,
# Nearest to can: will, for, if, and, ulcers, item, are, a,
# Nearest to called: a, along, is, kind, whose, combats, only, diffeomorphic,
# Nearest to zero: five, two, four, one, three, eight, six, seven,
# Nearest to institute: university, education, scr, vibe, seaborg, technology, ume, vrije,
# Nearest to event: events, paleocene, akin, quarrel, aberdare, necklaces, circled, celebrate,
# Nearest to heavy: minivans, vanilla, metal, grinder, shipboard, tso, shipowners, sensuous,
# Nearest to smith: exmoor, rigdon, greenpeace, footballer, polygamy, savior, photoshop, bak,
# Nearest to alternative: luton, oberlin, mirza, decibels, fraternities, spike, sib, royalties,
# Nearest to taking: align, course, blondie, kummer, stemming, longstreet, archie, quips,
# Nearest to engineering: humanities, pins, supplies, engineers, aerospace, sage, budapest, architectural,
# Nearest to road: tunnels, motorway, railway, roads, drove, revue, nontrivial, concede,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8332 0.0895 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8831 0.0880 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8865 0.0880 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8531 0.0878 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8737 0.0877 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8986 0.0890 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8663 0.0884 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8451 0.0903 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8670 0.0887 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9068 0.0883 sec/batch
# Nearest to all: in, two, for, thus, to, are, and, with,
# Nearest to while: it, in, well, cancellations, others, and, weak, have,
# Nearest to five: zero, two, four, six, one, three, eight, nine,
# Nearest to at: in, of, to, eastbourne, a, an, the, he,
# Nearest to between: the, of, a, and, bpm, beja, rolfe, whichever,
# Nearest to can: will, for, if, this, and, are, is, ulcers,
# Nearest to called: combats, is, a, whose, along, kind, also, pterosaurs,
# Nearest to zero: five, two, four, one, three, eight, six, nine,
# Nearest to institute: education, scr, vibe, university, ume, vrije, shanks, conservatorium,
# Nearest to event: events, paleocene, akin, aberdare, quarrel, celebrate, necklaces, as,
# Nearest to heavy: minivans, vanilla, metal, grinder, frankness, shipowners, sensuous, moraines,
# Nearest to smith: exmoor, rigdon, footballer, greenpeace, photoshop, quae, bak, polygamy,
# Nearest to alternative: mirza, fraternities, luton, sib, spike, decibels, royalties, deconstructionists,
# Nearest to taking: align, course, stemming, blondie, kummer, shortages, benjamins, party,
# Nearest to engineering: pins, humanities, supplies, aerospace, budapest, engineers, sage, kth,
# Nearest to road: tunnels, motorway, roads, railway, nontrivial, revue, drove, concede,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.9019 0.0887 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8625 0.0890 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8461 0.0902 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8466 0.0876 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9378 0.0886 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8767 0.0874 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9806 0.0878 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9078 0.0882 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9277 0.0883 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8525 0.0893 sec/batch
# Nearest to all: in, two, thus, are, for, and, pits, with,
# Nearest to while: in, it, and, have, well, cancellations, a, weak,
# Nearest to five: zero, two, one, four, three, six, nine, eight,
# Nearest to at: in, of, to, he, a, eastbourne, zero, nearby,
# Nearest to between: the, and, of, a, beja, whichever, bpm, flavio,
# Nearest to can: will, if, for, this, example, are, is, item,
# Nearest to called: a, kind, combats, along, is, whose, in, function,
# Nearest to zero: five, two, one, four, three, eight, six, nine,
# Nearest to institute: scr, education, vibe, ume, university, seaborg, directorship, technology,
# Nearest to event: events, paleocene, akin, quarrel, aberdare, vouchers, circled, break,
# Nearest to heavy: minivans, vanilla, metal, shipowners, sensuous, frankness, grinder, moraines,
# Nearest to smith: exmoor, polygamy, rigdon, greenpeace, savior, quae, bak, photoshop,
# Nearest to alternative: luton, mirza, sib, fraternities, oberlin, spike, decibels, northrop,
# Nearest to taking: align, blondie, kummer, course, shortages, stemming, longstreet, benjamins,
# Nearest to engineering: pins, humanities, budapest, supplies, sage, aerospace, baez, protestant,
# Nearest to road: tunnels, motorway, roads, revue, nontrivial, drove, railway, concede,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8163 0.0888 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8880 0.0884 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8196 0.0890 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8858 0.0896 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8785 0.0877 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8876 0.0896 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8957 0.0501 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8545 0.0834 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8650 0.0832 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8322 0.0819 sec/batch
# Nearest to all: in, the, for, and, thus, with, other, to,
# Nearest to while: in, have, it, well, weak, cancellations, others, and,
# Nearest to five: zero, two, one, four, three, six, eight, seven,
# Nearest to at: in, of, to, he, the, a, an, eastbourne,
# Nearest to between: the, a, and, of, beja, bpm, by, rolfe,
# Nearest to can: will, for, if, are, ulcers, is, predictable, generally,
# Nearest to called: a, in, kind, combats, is, along, whose, was,
# Nearest to zero: five, two, four, one, three, eight, six, seven,
# Nearest to institute: education, vibe, scr, university, technology, ume, vrije, seaborg,
# Nearest to event: events, paleocene, akin, aberdare, quarrel, vouchers, lockhart, break,
# Nearest to heavy: minivans, vanilla, metal, shipowners, frankness, sensuous, tso, progressions,
# Nearest to smith: exmoor, rigdon, footballer, polygamy, greenpeace, quae, photoshop, bak,
# Nearest to alternative: mirza, sib, spike, luton, oberlin, fraternities, northrop, deconstructionists,
# Nearest to taking: align, kummer, course, shortages, blondie, longstreet, stemming, toulouse,
# Nearest to engineering: humanities, pins, budapest, aerospace, supplies, sage, architectural, protestant,
# Nearest to road: motorway, tunnels, drove, roads, nontrivial, revue, railway, concede,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8319 0.0834 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8415 0.0810 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8435 0.0810 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8396 0.0819 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8829 0.0814 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8668 0.0806 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8914 0.0808 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7791 0.0812 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8430 0.0816 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8277 0.0815 sec/batch
# Nearest to all: in, the, and, are, for, two, to, thus,
# Nearest to while: it, well, have, in, weak, cancellations, others, and,
# Nearest to five: zero, two, four, one, three, six, eight, nine,
# Nearest to at: in, of, to, an, eastbourne, zero, he, part,
# Nearest to between: the, and, of, a, is, by, from, bpm,
# Nearest to can: will, for, if, is, are, a, and, this,
# Nearest to called: a, along, is, whose, in, kind, combats, this,
# Nearest to zero: five, two, one, four, three, eight, six, nine,
# Nearest to institute: education, university, vibe, scr, technology, ume, conservatorium, vrije,
# Nearest to event: events, paleocene, akin, circled, aberdare, lockhart, celebrate, quarrel,
# Nearest to heavy: minivans, vanilla, metal, shipowners, grinder, tso, sensuous, moraines,
# Nearest to smith: exmoor, rigdon, polygamy, savior, greenpeace, quae, discordant, photoshop,
# Nearest to alternative: oberlin, luton, mirza, sib, fraternities, spike, northrop, weathered,
# Nearest to taking: blondie, align, kummer, longstreet, course, stemming, shortages, toulouse,
# Nearest to engineering: humanities, pins, supplies, budapest, aerospace, engineers, architectural, sage,
# Nearest to road: tunnels, motorway, roads, revue, nontrivial, drove, railway, zadar,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7840 0.0833 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8557 0.0820 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8505 0.0814 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8468 0.0807 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8460 0.0814 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9131 0.0817 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8725 0.0811 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8247 0.0809 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8502 0.0822 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8740 0.0814 sec/batch
# Nearest to all: in, and, thus, are, two, the, for, to,
# Nearest to while: it, have, in, weak, cancellations, well, and, others,
# Nearest to five: zero, two, four, one, three, six, eight, nine,
# Nearest to at: in, of, to, an, eastbourne, it, zero, he,
# Nearest to between: the, and, of, beja, from, a, bpm, is,
# Nearest to can: will, for, if, this, is, and, a, are,
# Nearest to called: kind, along, a, whose, combats, this, is, pterosaurs,
# Nearest to zero: five, two, one, four, three, eight, six, nine,
# Nearest to institute: education, university, scr, vibe, vrije, technology, ume, seaborg,
# Nearest to event: events, paleocene, akin, circled, break, aberdare, lockhart, as,
# Nearest to heavy: vanilla, minivans, metal, shipowners, grinder, tso, sensuous, frankness,
# Nearest to smith: exmoor, rigdon, greenpeace, polygamy, interlaced, footballer, quae, discordant,
# Nearest to alternative: oberlin, fraternities, luton, sib, mirza, spike, northrop, weathered,
# Nearest to taking: align, blondie, kummer, course, composites, quips, longstreet, manipulations,
# Nearest to engineering: humanities, pins, supplies, budapest, aerospace, engineers, sage, railroads,
# Nearest to road: tunnels, motorway, roads, revue, drove, nontrivial, zadar, tulane,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8914 0.0821 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8763 0.0813 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8485 0.0819 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8555 0.0818 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8750 0.0805 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8647 0.0816 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8504 0.0818 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8933 0.0814 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8093 0.0813 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8164 0.0806 sec/batch
# Nearest to all: and, in, for, two, are, thus, the, other,
# Nearest to while: it, in, have, well, weak, others, and, soon,
# Nearest to five: zero, two, four, one, six, three, eight, seven,
# Nearest to at: in, of, to, a, eastbourne, an, zero, seven,
# Nearest to between: the, and, of, from, is, beja, a, by,
# Nearest to can: for, will, if, a, this, be, is, and,
# Nearest to called: a, along, combats, this, whose, in, kind, also,
# Nearest to zero: five, two, one, four, three, eight, six, nine,
# Nearest to institute: education, scr, vibe, university, vrije, ume, outranks, seaborg,
# Nearest to event: events, paleocene, akin, circled, celebrate, aberdare, quarrel, break,
# Nearest to heavy: vanilla, minivans, metal, shipowners, tso, grinder, frankness, sensuous,
# Nearest to smith: exmoor, rigdon, greenpeace, polygamy, footballer, interlaced, bak, photoshop,
# Nearest to alternative: fraternities, sib, luton, oberlin, mirza, spike, northrop, weathered,
# Nearest to taking: align, blondie, kummer, party, stemming, composites, quips, course,
# Nearest to engineering: pins, humanities, supplies, budapest, aerospace, sage, railroads, engineers,
# Nearest to road: motorway, tunnels, roads, revue, nontrivial, zadar, drove, railway,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8894 0.0823 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7924 0.0811 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9492 0.0815 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9286 0.0816 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8924 0.0821 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8544 0.0809 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8000 0.0811 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8365 0.0819 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7697 0.0813 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8811 0.0808 sec/batch
# Nearest to all: in, and, for, are, two, thus, other, the,
# Nearest to while: it, have, in, and, well, are, others, a,
# Nearest to five: zero, two, one, four, three, six, eight, seven,
# Nearest to at: in, of, to, an, a, the, eastbourne, zero,
# Nearest to between: the, and, of, beja, is, from, a, bpm,
# Nearest to can: will, if, for, is, be, ulcers, this, are,
# Nearest to called: a, this, whose, in, kind, is, along, combats,
# Nearest to zero: five, two, one, four, three, eight, six, nine,
# Nearest to institute: vibe, education, scr, university, vrije, ume, outranks, residency,
# Nearest to event: events, paleocene, akin, celebrate, break, aberdare, quarrel, vouchers,
# Nearest to heavy: vanilla, metal, minivans, tso, shipowners, grinder, sensuous, frankness,
# Nearest to smith: exmoor, polygamy, rigdon, greenpeace, interlaced, savior, bak, thereof,
# Nearest to alternative: luton, mirza, fraternities, oberlin, sib, spike, weathered, andree,
# Nearest to taking: blondie, align, composites, longstreet, stemming, kummer, party, toulouse,
# Nearest to engineering: pins, humanities, budapest, supplies, aerospace, engineers, sage, depended,
# Nearest to road: tunnels, roads, motorway, nontrivial, revue, drove, zadar, tiamat,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8736 0.0824 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8566 0.0818 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
